# %% [markdown]
# # Data Mining Project: Milestone 1 (Part 2)
# ### Web Scraping (Part 2): Scrap box office data from boxofficemojo.com
# 1. Using selenium, open a browser and browse to https://www.boxofficemojo.com/
# 2. Search the desired movie title on boxofficemojo.com
# 3. Click into the first result page
# 3. Extract the box office data of the movie

# %%
import re
import time    
import joblib
import pandas as pd
import requests
from bs4 import BeautifulSoup
from selenium import webdriver                    
from selenium.webdriver.common.keys import Keys                      

def open_browser():
    '''Open a browser using selenium'''
    browser = webdriver.Firefox(executable_path="./geckodriver-v0.25.0-win64/geckodriver.exe")  
    return browser


def get_text(browser, xpath):
    '''Extract the text by xpath'''
    try:
        return browser.find_elements_by_xpath(xpath)[0].text 
    except:
        return None

def scrap_box_office_data(browser, movie_title):
    try:
        URL = "https://www.boxofficemojo.com/date"
        browser.get(URL) 
        time.sleep(0.5)  
        
        # Search the movie title on boxofficemojo.com
        search = browser.find_elements_by_xpath('//*[@id="mojo-search-text-input"]')[0]
        search.send_keys(Keys.ESCAPE) 
        
        search = browser.find_elements_by_xpath('//*[@id="mojo-search-text-input"]')[0]
        time.sleep(1)  
        search.send_keys(movie_title)
        time.sleep(0.5)  
        search.send_keys(Keys.ENTER) 
        time.sleep(2)      
        
        # On the search result page, click on the first result to go to the desired movie page
        first_search = browser.find_elements_by_xpath('/html/body/div[1]/main/div/div/div/div[1]/div/div[2]/a')
        if len(first_search) == 0:
            print("No movie found:", movie_title)
            return {}
        else:
            movie_page_url = first_search[0].get_property("href")
            first_search[0].click()
        
#         # On the movie page, scrap all the box office data    
        domestic_xpath = '/html/body/div[1]/main/div/div[3]/div[1]/div/div[1]/span[2]/span'
        foreign_xpath = '/html/body/div[1]/main/div/div[3]/div[1]/div/div[2]/span[2]/span'
        total_xpath = '/html/body/div[1]/main/div/div[3]/div[1]/div/div[3]/span[2]/span'
        
        distributor_xpath = '/html/body/div[1]/main/div/div[3]/div[4]/div[1]/span[2]'
        opening_xpath = '/html/body/div[1]/main/div/div[3]/div[4]/div[2]/span[2]/span'
        mpaa_xpath = '/html/body/div[1]/main/div/div[3]/div[4]/div[4]/span[2]'
        mpaa_confirm_xpath = '/html/body/div[1]/main/div/div[3]/div[4]/div[4]/span[1]'
        markets_xpath = '/html/body/div[1]/main/div/div[5]/div/div/table/tbody/tr[2]/td[3]'
        
        mpaa_confirm = get_text(browser, mpaa_confirm_xpath)
        
        box_office_dict = {}
        box_office_dict["movie_title"] = movie_title
        box_office_dict["domestic_gross"] = get_text(browser, domestic_xpath)
        box_office_dict["foreign_gross"] = get_text(browser, foreign_xpath)
        box_office_dict["total_gross"] = get_text(browser, total_xpath)
#         box_office_dict["distributor"] = get_text(browser, distributor_xpath)
        box_office_dict["domestic_opening"] = get_text(browser, opening_xpath)
        if mpaa_confirm == "MPAA":
            box_office_dict['mpaa'] = get_text(browser, mpaa_xpath)
        else:
            box_office_dict['mpaa'] = None
        box_office_dict['markets'] = get_text(browser, markets_xpath)

        return box_office_dict
    except Exception as err:
        print("No movie found err:", movie_title, err)
        return {}

# %% [markdown]
# ### Load the 250 movie titles that we obtained from Part 1.

# %%
df = pd.read_csv("movie_info_5000.csv")
df.shape
# Out:
# (4878, 16)

# %% [markdown]
# ### Scrap the box office data of the 250 movies.
# *This will take approximately 20 minutes.*

# %%
# %%time 
browser = open_browser()

box_office_list = []
for movie_title in df.title.values[1000:2000]:
    data = scrap_box_office_data(browser, movie_title)
    box_office_list.append(data)
    
browser.close()
# Out:
# No movie found: Santa & Andrés
# No movie found: The Good Postman
# No movie found: The Evil Within
# No movie found: A Gray State
# No movie found: The Villainess (Ak-Nyeo)
# No movie found: Rift (Rökkur)
# No movie found: Jim & Andy: The Great Beyond - Featuring a Very Special, Contractually Obligated Mention of Tony Clifton
# No movie found: A Christmas Prince
# No movie found: One October
# No movie found: Most Likely to Murder
# No movie found: Batman Ninja
# No movie found: Tremors: A Cold Day in Hell
# No movie found: The Kissing Booth
# No movie found: John Mulaney: Kid Gorgeous at Radio City
# No movie found: Hari Kondabolu: Warn Your Relatives
# No movie found: Ali Wong: Hard Knock Wife
# No movie found: Skin in the Game
# No movie found: Crown and Anchor
# No movie found: Making Babies
# No movie found: Miss Arizona
# No movie found: Aziz Ansari: Right Now
# No movie found: Moses and Aaron
# No movie found: Everybody Knows... Elizabeth Murray
# No movie found: Joan Didion: The Center Will Not Hold
# No movie found: The World Is Yours (Le monde ou rien)
# No movie found: A Christmas Prince: The Royal Wedding
# No movie found: Viking Destiny (Of Gods and Warriors)
# No movie found: You Might Be the Killer
# No movie found: The Christmas Chronicles
# No movie found: Bob Lazar: Area 51 & Flying Saucers
# No movie found: Equal Means Equal
# No movie found: Killing for Love (Das Versprechen)
# No movie found: Let the Sunshine In (Un beau soleil intérieur)
# No movie found: Come Sunday
# No movie found: The Escape of Prisoner 614
# No movie found: The Rachel Divide
# No movie found: I Am Not An Easy Man (Je Ne Suis Pas Un Homme Facile)
# No movie found: Candy Jar
# No movie found: The Meyerowitz Stories (New and Selected)
# No movie found: A Very Sordid Wedding
# No movie found: Batman vs. Two-Face
# No movie found: Wheelman
# No movie found: Patton Oswalt: Annihilation
# No movie found: Half Magic
# No movie found: King In The Wilderness
# No movie found: First Match
# No movie found: Suicide Squad: Hell to Pay
# No movie found: Happy Anniversary
# No movie found: Do You Trust this Computer?
# No movie found: The New Romantic
# No movie found: The Last Sharknado: It's About Time
# No movie found: Lez Bomb
# No movie found: May the Devil Take You (Sebelum iblis menjemput)
# No movie found: Intensive Care
# No movie found: Swiped
# No movie found: The Princess Switch
# No movie found: Midnight Return: The Story of Billy Hayes and Turkey
# No movie found: Small Town Crime
# No movie found: The Divine Order (Die göttliche Ordnung)
# No movie found: Arthur Miller: Writer
# No movie found: I Remember You (Eg Man Big)
# No movie found: Hearing Is Believing
# No movie found: Can't Stop, Won't Stop: A Bad Boy Story
# No movie found: Shimmer Lake
# No movie found: Oh, Hello On Broadway
# No movie found: Rory Scovel Tries Stand-up For The First Time
# No movie found: Awakening the Zodiac
# No movie found: King Charles III
# No movie found: Chasing Coral
# No movie found: Imperial Dreams
# No movie found: Passage to Mars
# No movie found: Dr. Feelgood: Dealer or Healer?
# No movie found: Roger Corman's Death Race 2050
# No movie found: Neal Brennan: 3 Mics
# No movie found: Reset (Relève: Histoire d'une création)
# No movie found: The Monkey King 2 (San Da Bai Gu Jing)
# No movie found: Claire in Motion
# No movie found: Bright Lights: Starring Carrie Fisher and Debbie Reynolds
# No movie found: Attack of the Lederhosen Zombies
# No movie found: Jim Gaffigan: Cinco
# No movie found: The Dark Tapes
# No movie found: Teen Titans: The Judas Contract
# No movie found: Rodney King
# No movie found: First They Killed My Father
# No movie found: Man in Red Bandana
# No movie found: The Good Catholic
# No movie found: Easy Living
# No movie found: Jerry Before Seinfeld
# No movie found: Gaga: Five Foot Two
# No movie found: Odd Brodsky
# No movie found: The Rocky Horror Picture Show: Let's Do the Time Warp Again
# No movie found: Olympic Pride, American Prejudice
# No movie found: Be My Cat: A Film for Anne
# No movie found: Run the Tide
# No movie found: Fake It So Real
# No movie found: 808
# No movie found: Let's Be Evil
# No movie found: Kill Ratio
# No movie found: Fort Tilden
# No movie found: Uncle Kent 2
# No movie found: The Similars (Los Parecidos)
# No movie found: The True Memoirs of an International Assassin
# No movie found: Marathon: The Patriots Day Bombing
# No movie found: Little Fauss and Big Halsy
# No movie found: Jianyu (Reign of Assassins)
# No movie found: The Beat Beneath My Feet
# No movie found: The Apostate (El Apóstata)
# No movie found: Who's Driving Doug
# No movie found: I Am the Pretty Thing That Lives in the House
# No movie found: Bayou Maharajah
# No movie found: The Siege of Jadotville
# No movie found: Len and Company
# Wall time: 2h 17min 27s

# %% [markdown]
# #### Temporarily store these data in CSV.
# *These data will be stored in the Hive Data Warehouse in the next milestone.*

# %%
box_office_df = pd.DataFrame(box_office_list)

print(box_office_df.shape)
box_office_df.head()
# Out:
# (1000, 7)
#   domestic_gross domestic_opening foreign_gross     markets  \
# 0    $33,800,859         $161,558   $10,179,962  28 markets
# 1           None             None      $252,917      France
# 2           None             None      $694,981   9 markets
# 3       $406,284          $16,626          $626    Domestic
# 4            NaN              NaN           NaN         NaN
#
#                                     movie_title   mpaa  total_gross
# 0                                    Wind River   None  $43,980,821
# 1                            The Night Watchmen   None     $252,917
# 2                          The Secret Scripture  PG-13     $694,981
# 3  Chasing Trane: The John Coltrane Documentary   None     $406,910
# 4                                           NaN    NaN          NaN

# %%
box_office_df = box_office_df.loc[~box_office_df.isna().all(axis = 1),:]
box_office_df.shape
# Out:
# (811, 7)

# %%
box_office_df.to_csv("movie_box_office_5000_2.csv", index = False)
